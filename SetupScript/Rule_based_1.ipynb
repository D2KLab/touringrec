# %%
import pandas as pd
import numpy as np

# %%
df_test = pd.read_csv('test.csv')

# %%
def explode_position_scalable(df_in, col_expl, pipe='|'):
    """Explode column col_expl of array type into multiple rows."""
    
    n = 60000  #chunk row size
    list_df = [df_in[i:i+n] for i in range(0,df_in.shape[0],n)]
    # Handle the first alone to have the correct headers
    df_x = explode_position(list_df[0], col_expl, flag_conversion=False, pipe_type=pipe)
    df_x = df_x.rename(columns={col_expl:'item_id'})
    df_x.to_csv('exploded.csv', index=False)
    list_df.pop(0)
    for df_x in list_df:
        df_x = explode_position(df_x, col_expl, flag_conversion=False, pipe_type=pipe)
        df_x = df_x.rename(columns={col_expl:'item_id'})
        df_x.to_csv('exploded.csv', mode='a', header=False, index=False)

    df_out = pd.read_csv('exploded.csv')

    os.remove('exploded.csv')
    return df_out
  
def explode_position(df_in, col_expl, flag_conversion = True, pipe_type='|'):
    """Explode column col_expl of array type into multiple rows."""

    df = df_in.copy()
    if(pipe_type== '|'):
        df.loc[:, col_expl] = df[col_expl].apply(string_to_array)
    elif(pipe_type==' '):
        df.loc[:, col_expl] = df[col_expl].apply(space_to_array)
    df.loc[:, 'position'] = df[col_expl].apply(get_position)
    df_out = pd.DataFrame(
        {col: np.repeat(df[col].values,
                        df[col_expl].str.len())
         for col in df.columns.drop(col_expl)}
    )
    df_out.loc[:, col_expl] = np.concatenate(df[col_expl].values)
    df_out.loc[:, 'position'] = np.concatenate(df['position'].values)
    if(flag_conversion):
        df_out.loc[:, col_expl] = df_out[col_expl].apply(int)

    return df_out
  
def string_to_array(s):
    """Convert pipe separated string to array."""

    if isinstance(s, str):
        out = s.split("|")
    elif math.isnan(s):
        out = []
    else:
        raise ValueError("Value must be either string of nan")
    return out
  
def get_position(l):
    pos = []
    for i in range(0,len(l)):
        pos.append(i)
    return pos

def create_recent_index(df_orig, grouped=False):
    # distinct_hotel = group.reference.drop_duplicates().values
    # dict = {}
    # counter = 0
    # for x in distinct_hotel:
    #     dict[x] = counter
    #     counter += 1
    df_list_int = df_orig.groupby('session_id').apply(lambda x: get_list_session_interactions(x)).reset_index(name='all_interactions')
    df_list_int = df_list_int[['session_id', 'all_interactions']]
    if(grouped):
        return df_list_int
    df_orig = (df_orig.merge(df_list_int, left_on=['session_id'], right_on=['session_id'], how="left"))
    #del df_orig['all_interactions']
    return df_orig
  
def get_list_session_interactions(group):
    group = group[~group['reference'].isnull()]
    group = group[group['action_type'] == 'clickout item']
    group.loc[:,'reference'] = group['reference'].apply(str)
    list_values = group.reference.drop_duplicates()
    joined = " ".join(list_values)
    return joined

def get_submission_target(df):
    """Identify target rows with missing click outs."""

    mask = df["reference"].isnull() & (df["action_type"] == "clickout item")
    df_out = df[mask]

    return df_out

# %%
def get_clickouts(df_test):
    df_test['step_max'] = df_test.groupby(['user_id'])['step'].transform(max)
    df_clickout = df_test[(df_test['step_max'] == df_test['step']) & (df_test['action_type'] == 'clickout item')]
    del df_clickout['step_max']
    return df_clickout

# %%
mask = (df_test["action_type"] == "clickout item") | (df_test["action_type"] == "interaction item rating") | (df_test["action_type"] == "interaction item image") | (df_test["action_type"] == "interaction item deals")
df_test = df_test[mask]

# %%
df_recent = create_recent_index(df_test)
df_recent
# Out:
#               user_id     session_id   timestamp  step  \
# 0        03P4VFKK12UO  325fafb5fa450  1541107435    17
# 1        03P4VFKK12UO  325fafb5fa450  1541107435    18
# 2        03P4VFKK12UO  325fafb5fa450  1541107457    19
# 3        03P4VFKK12UO  325fafb5fa450  1541107457    20
# 4        03P4VFKK12UO  325fafb5fa450  1541107467    21
# 5        03P4VFKK12UO  325fafb5fa450  1541107467    22
# 6        03P4VFKK12UO  325fafb5fa450  1541107467    23
# 7        03P4VFKK12UO  325fafb5fa450  1541107467    24
# 8        03P4VFKK12UO  325fafb5fa450  1541107467    25
# 9        03P4VFKK12UO  325fafb5fa450  1541107467    26
# 10       03P4VFKK12UO  325fafb5fa450  1541107467    27
# 11       03P4VFKK12UO  325fafb5fa450  1541107467    28
# 12       03P4VFKK12UO  325fafb5fa450  1541107467    29
# 13       03P4VFKK12UO  325fafb5fa450  1541107477    30
# 14       03P4VFKK12UO  325fafb5fa450  1541107477    31
# 15       03P4VFKK12UO  325fafb5fa450  1541107477    32
# 16       03P4VFKK12UO  325fafb5fa450  1541107477    33
# 17       03P4VFKK12UO  325fafb5fa450  1541107487    34
# 18       03P4VFKK12UO  325fafb5fa450  1541107487    35
# 19       03P4VFKK12UO  325fafb5fa450  1541107487    36
# 20       03P4VFKK12UO  325fafb5fa450  1541107487    37
# 21       03P4VFKK12UO  325fafb5fa450  1541107487    38
# 22       03P4VFKK12UO  325fafb5fa450  1541107487    39
# 23       03P4VFKK12UO  325fafb5fa450  1541107487    40
# 24       03P4VFKK12UO  325fafb5fa450  1541107487    41
# 25       03P4VFKK12UO  325fafb5fa450  1541107487    42
# 26       03P4VFKK12UO  325fafb5fa450  1541107487    43
# 27       03P4VFKK12UO  325fafb5fa450  1541107487    44
# 28       03P4VFKK12UO  325fafb5fa450  1541107497    45
# 29       03P4VFKK12UO  325fafb5fa450  1541107497    46
# ...               ...            ...         ...   ...
# 2743298  ZB7RY7V0OZWC  8b26928793215  1541480067     9
# 2743299  ZB7RY7V0OZWC  8b26928793215  1541480077    10
# 2743300  ZB7RY7V0OZWC  8b26928793215  1541480077    11
# 2743301  ZB7RY7V0OZWC  8b26928793215  1541480077    12
# 2743302  ZB7RY7V0OZWC  8b26928793215  1541480077    13
# 2743303  ZB7RY7V0OZWC  8b26928793215  1541480077    14
# 2743304  ZB7RY7V0OZWC  8b26928793215  1541480077    15
# 2743305  ZB7RY7V0OZWC  8b26928793215  1541480106    17
# 2743306  ZB7RY7V0OZWC  8b26928793215  1541480529    18
# 2743307  ZB7RY7V0OZWC  8b26928793215  1541480529    19
# 2743308  ZB7RY7V0OZWC  8b26928793215  1541480539    20
# 2743309  ZB7RY7V0OZWC  8b26928793215  1541480539    21
# 2743310  ZB7RY7V0OZWC  8b26928793215  1541480549    22
# 2743311  ZB7RY7V0OZWC  8b26928793215  1541480549    23
# 2743312  ZB7RY7V0OZWC  8b26928793215  1541480549    24
# 2743313  ZB7RY7V0OZWC  8b26928793215  1541480549    25
# 2743314  ZB7RY7V0OZWC  8b26928793215  1541480556    26
# 2743315  ZB7RY7V0OZWC  8b26928793215  1541480559    27
# 2743316  ZB7RY7V0OZWC  8b26928793215  1541480559    28
# 2743317  ZB7RY7V0OZWC  8b26928793215  1541480559    29
# 2743318  ZB7RY7V0OZWC  8b26928793215  1541480559    30
# 2743319  ZB7RY7V0OZWC  8b26928793215  1541480559    31
# 2743320  ZB7RY7V0OZWC  8b26928793215  1541480907    32
# 2743321  ZGLL26UBPRNB  f79dabc52921a  1541536456     1
# 2743322  ZRYLZHWFLXM5  88fb00a1effde  1541507231     3
# 2743323  ZRYLZHWFLXM5  88fb00a1effde  1541507231     4
# 2743324  ZRYLZHWFLXM5  88fb00a1effde  1541507231     5
# 2743325  ZRYLZHWFLXM5  88fb00a1effde  1541507265     6
# 2743326  ZRYLZHWFLXM5  88fb00a1effde  1541507265     7
# 2743327  ZRYLZHWFLXM5  88fb00a1effde  1541507265     8
#
#                     action_type reference platform                     city  \
# 0        interaction item image     65685       US         Bakersfield, USA
# 1        interaction item image     65685       US         Bakersfield, USA
# 2        interaction item image     65685       US         Bakersfield, USA
# 3        interaction item image     65685       US         Bakersfield, USA
# 4        interaction item image     65685       US         Bakersfield, USA
# 5        interaction item image     65685       US         Bakersfield, USA
# 6        interaction item image     65685       US         Bakersfield, USA
# 7        interaction item image     65685       US         Bakersfield, USA
# 8        interaction item image     65685       US         Bakersfield, USA
# 9        interaction item image     65685       US         Bakersfield, USA
# 10       interaction item image     65685       US         Bakersfield, USA
# 11       interaction item image     65685       US         Bakersfield, USA
# 12       interaction item image     65685       US         Bakersfield, USA
# 13       interaction item image     65685       US         Bakersfield, USA
# 14       interaction item image     65685       US         Bakersfield, USA
# 15       interaction item image     65685       US         Bakersfield, USA
# 16       interaction item image     65685       US         Bakersfield, USA
# 17       interaction item image     65685       US         Bakersfield, USA
# 18       interaction item image     65685       US         Bakersfield, USA
# 19       interaction item image     65685       US         Bakersfield, USA
# 20       interaction item image     65685       US         Bakersfield, USA
# 21       interaction item image     65685       US         Bakersfield, USA
# 22       interaction item image     65685       US         Bakersfield, USA
# 23       interaction item image     65685       US         Bakersfield, USA
# 24       interaction item image     65685       US         Bakersfield, USA
# 25       interaction item image     65685       US         Bakersfield, USA
# 26       interaction item image     65685       US         Bakersfield, USA
# 27       interaction item image     65685       US         Bakersfield, USA
# 28       interaction item image     65685       US         Bakersfield, USA
# 29       interaction item image     65685       US         Bakersfield, USA
# ...                         ...       ...      ...                      ...
# 2743298  interaction item image   3438490       MY  Petaling Jaya, Malaysia
# 2743299  interaction item image   3438490       MY  Petaling Jaya, Malaysia
# 2743300  interaction item image   3438490       MY  Petaling Jaya, Malaysia
# 2743301  interaction item image   3438490       MY  Petaling Jaya, Malaysia
# 2743302  interaction item image   3438490       MY  Petaling Jaya, Malaysia
# 2743303  interaction item image   3438490       MY  Petaling Jaya, Malaysia
# 2743304  interaction item image   3438490       MY  Petaling Jaya, Malaysia
# 2743305           clickout item   1716237       MY  Petaling Jaya, Malaysia
# 2743306  interaction item image   5158194       MY  Petaling Jaya, Malaysia
# 2743307  interaction item image   5158194       MY  Petaling Jaya, Malaysia
# 2743308  interaction item image   5158194       MY  Petaling Jaya, Malaysia
# 2743309  interaction item image   5158194       MY  Petaling Jaya, Malaysia
# 2743310  interaction item image   5158194       MY  Petaling Jaya, Malaysia
# 2743311  interaction item image   5158194       MY  Petaling Jaya, Malaysia
# 2743312  interaction item image   5158194       MY  Petaling Jaya, Malaysia
# 2743313  interaction item image   5158194       MY  Petaling Jaya, Malaysia
# 2743314           clickout item   5158194       MY  Petaling Jaya, Malaysia
# 2743315  interaction item image   5158194       MY  Petaling Jaya, Malaysia
# 2743316  interaction item image   5158194       MY  Petaling Jaya, Malaysia
# 2743317  interaction item image   5158194       MY  Petaling Jaya, Malaysia
# 2743318  interaction item image   5158194       MY  Petaling Jaya, Malaysia
# 2743319  interaction item image   5158194       MY  Petaling Jaya, Malaysia
# 2743320           clickout item       NaN       MY  Petaling Jaya, Malaysia
# 2743321           clickout item       NaN       PH      Manila, Philippines
# 2743322  interaction item image   8254824       DE   London, United Kingdom
# 2743323  interaction item image   8254824       DE   London, United Kingdom
# 2743324  interaction item deals   8254824       DE   London, United Kingdom
# 2743325  interaction item image   8254824       DE   London, United Kingdom
# 2743326  interaction item image   8254824       DE   London, United Kingdom
# 2743327  interaction item deals   8254824       DE   London, United Kingdom
#
#           device current_filters  \
# 0        desktop             NaN
# 1        desktop             NaN
# 2        desktop             NaN
# 3        desktop             NaN
# 4        desktop             NaN
# 5        desktop             NaN
# 6        desktop             NaN
# 7        desktop             NaN
# 8        desktop             NaN
# 9        desktop             NaN
# 10       desktop             NaN
# 11       desktop             NaN
# 12       desktop             NaN
# 13       desktop             NaN
# 14       desktop             NaN
# 15       desktop             NaN
# 16       desktop             NaN
# 17       desktop             NaN
# 18       desktop             NaN
# 19       desktop             NaN
# 20       desktop             NaN
# 21       desktop             NaN
# 22       desktop             NaN
# 23       desktop             NaN
# 24       desktop             NaN
# 25       desktop             NaN
# 26       desktop             NaN
# 27       desktop             NaN
# 28       desktop             NaN
# 29       desktop             NaN
# ...          ...             ...
# 2743298   mobile             NaN
# 2743299   mobile             NaN
# 2743300   mobile             NaN
# 2743301   mobile             NaN
# 2743302   mobile             NaN
# 2743303   mobile             NaN
# 2743304   mobile             NaN
# 2743305   mobile             NaN
# 2743306   mobile             NaN
# 2743307   mobile             NaN
# 2743308   mobile             NaN
# 2743309   mobile             NaN
# 2743310   mobile             NaN
# 2743311   mobile             NaN
# 2743312   mobile             NaN
# 2743313   mobile             NaN
# 2743314   mobile             NaN
# 2743315   mobile             NaN
# 2743316   mobile             NaN
# 2743317   mobile             NaN
# 2743318   mobile             NaN
# 2743319   mobile             NaN
# 2743320   mobile             NaN
# 2743321   mobile             NaN
# 2743322   mobile             NaN
# 2743323   mobile             NaN
# 2743324   mobile             NaN
# 2743325   mobile             NaN
# 2743326   mobile             NaN
# 2743327   mobile             NaN
#
#                                                impressions  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
# 10                                                     NaN
# 11                                                     NaN
# 12                                                     NaN
# 13                                                     NaN
# 14                                                     NaN
# 15                                                     NaN
# 16                                                     NaN
# 17                                                     NaN
# 18                                                     NaN
# 19                                                     NaN
# 20                                                     NaN
# 21                                                     NaN
# 22                                                     NaN
# 23                                                     NaN
# 24                                                     NaN
# 25                                                     NaN
# 26                                                     NaN
# 27                                                     NaN
# 28                                                     NaN
# 29                                                     NaN
# ...                                                    ...
# 2743298                                                NaN
# 2743299                                                NaN
# 2743300                                                NaN
# 2743301                                                NaN
# 2743302                                                NaN
# 2743303                                                NaN
# 2743304                                                NaN
# 2743305  693841|2402030|8153130|6276246|3755330|3438490...
# 2743306                                                NaN
# 2743307                                                NaN
# 2743308                                                NaN
# 2743309                                                NaN
# 2743310                                                NaN
# 2743311                                                NaN
# 2743312                                                NaN
# 2743313                                                NaN
# 2743314  693841|2402030|8153130|6276246|3755330|3438490...
# 2743315                                                NaN
# 2743316                                                NaN
# 2743317                                                NaN
# 2743318                                                NaN
# 2743319                                                NaN
# 2743320  693841|2402030|8153130|6276246|3755330|3438490...
# 2743321  2713516|203851|203861|203951|320736|320786|124...
# 2743322                                                NaN
# 2743323                                                NaN
# 2743324                                                NaN
# 2743325                                                NaN
# 2743326                                                NaN
# 2743327                                                NaN
#
#                                                     prices  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
# 10                                                     NaN
# 11                                                     NaN
# 12                                                     NaN
# 13                                                     NaN
# 14                                                     NaN
# 15                                                     NaN
# 16                                                     NaN
# 17                                                     NaN
# 18                                                     NaN
# 19                                                     NaN
# 20                                                     NaN
# 21                                                     NaN
# 22                                                     NaN
# 23                                                     NaN
# 24                                                     NaN
# 25                                                     NaN
# 26                                                     NaN
# 27                                                     NaN
# 28                                                     NaN
# 29                                                     NaN
# ...                                                    ...
# 2743298                                                NaN
# 2743299                                                NaN
# 2743300                                                NaN
# 2743301                                                NaN
# 2743302                                                NaN
# 2743303                                                NaN
# 2743304                                                NaN
# 2743305  47|51|146|71|63|39|53|82|21|34|11|72|37|34|16|...
# 2743306                                                NaN
# 2743307                                                NaN
# 2743308                                                NaN
# 2743309                                                NaN
# 2743310                                                NaN
# 2743311                                                NaN
# 2743312                                                NaN
# 2743313                                                NaN
# 2743314  47|51|146|71|63|39|53|82|21|34|11|72|37|34|16|...
# 2743315                                                NaN
# 2743316                                                NaN
# 2743317                                                NaN
# 2743318                                                NaN
# 2743319                                                NaN
# 2743320  47|51|146|71|63|39|53|82|21|34|11|72|37|34|16|...
# 2743321  22|93|157|120|52|97|262|68|109|136|242|34|21|1...
# 2743322                                                NaN
# 2743323                                                NaN
# 2743324                                                NaN
# 2743325                                                NaN
# 2743326                                                NaN
# 2743327                                                NaN
#
#                 all_interactions
# 0                          65685
# 1                          65685
# 2                          65685
# 3                          65685
# 4                          65685
# 5                          65685
# 6                          65685
# 7                          65685
# 8                          65685
# 9                          65685
# 10                         65685
# 11                         65685
# 12                         65685
# 13                         65685
# 14                         65685
# 15                         65685
# 16                         65685
# 17                         65685
# 18                         65685
# 19                         65685
# 20                         65685
# 21                         65685
# 22                         65685
# 23                         65685
# 24                         65685
# 25                         65685
# 26                         65685
# 27                         65685
# 28                         65685
# 29                         65685
# ...                          ...
# 2743298  8153130 1716237 5158194
# 2743299  8153130 1716237 5158194
# 2743300  8153130 1716237 5158194
# 2743301  8153130 1716237 5158194
# 2743302  8153130 1716237 5158194
# 2743303  8153130 1716237 5158194
# 2743304  8153130 1716237 5158194
# 2743305  8153130 1716237 5158194
# 2743306  8153130 1716237 5158194
# 2743307  8153130 1716237 5158194
# 2743308  8153130 1716237 5158194
# 2743309  8153130 1716237 5158194
# 2743310  8153130 1716237 5158194
# 2743311  8153130 1716237 5158194
# 2743312  8153130 1716237 5158194
# 2743313  8153130 1716237 5158194
# 2743314  8153130 1716237 5158194
# 2743315  8153130 1716237 5158194
# 2743316  8153130 1716237 5158194
# 2743317  8153130 1716237 5158194
# 2743318  8153130 1716237 5158194
# 2743319  8153130 1716237 5158194
# 2743320  8153130 1716237 5158194
# 2743321
# 2743322
# 2743323
# 2743324
# 2743325
# 2743326
# 2743327
#
# [2743328 rows x 13 columns]

# %%
def complete_prediction(df_test_nation):
    df_test_nation['item_recommendations'] = df_test_nation.apply(lambda x: fill_recs(x.impressions), axis=1)
    #print('No prediction for #' + str(df_missed.shape[0]) + 'items')
    df_out_nation = df_test_nation[['user_id', 'session_id', 'timestamp','step', 'item_recommendations']]
    return df_out_nation

def list_to_space_string(l):
    """Return a space separated string from a list"""
    s = " ".join(l)
    return s

def fill_recs(imp):
    l = imp.split('|')
    return list_to_space_string(l)

# %%
def complete_prediction_recent(df):
    df['item_recommendations'] = df.apply(lambda x: concat_interactions(x), axis=1)
    df_out = df[['user_id', 'session_id', 'timestamp','step', 'item_recommendations']]
    return df_out

def concat_interactions(row):
    spl_int = row.all_interactions.split(' ')
    spl_int = spl_int[::-1]
    spl_imp = row.impressions.split('|')
    result = []
    for i in spl_int:
        result.append(str(i))
    for i in spl_imp:
        if(str(i) not in result):
            result.append(str(i))
    return " ".join(result)

# %%
df_sub = get_submission_target(df_recent)

# %%
df_predicted = df_sub[df_sub['all_interactions'] != '']
df_not_predicted = df_sub[df_sub['all_interactions'] == '']

# %%
df_not_predicted = complete_prediction(df_not_predicted)
df_not_predicted.head()
# Out:
# /usr/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#          user_id     session_id   timestamp  step  \
# 39  06S61EKCW1JY  22b9deb2da8f7  1541075258     1
# 81  0NN8D1GWBW1F  84316dcbfb8e3  1541042711     1
# 84  0O1CTEP95YKQ  af793494b5f84  1541113537    22
# 87  0T819ODEIRA4  7643893620070  1541085062     7
# 88  0VNR91BTRLCP  0c086494b8b9b  1541062145     1
#
#                                  item_recommendations
# 39  6721 6724 40109 147227 80983 6719 40718 119405...
# 81  9164598 1400686 2216204 2817576 4775794 568427...
# 84  69086 8533 925367 58949 61049 8581 8517 77520 ...
# 87  162011 52319 5170834 9332768 6398694 1830581 5...
# 88  1204316 2140652 107674 1072440 2555490 2181166...

# %%
df_predicted = complete_prediction_recent(df_predicted)
df_predicted
# Out:
# /usr/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#               user_id     session_id   timestamp  step  \
# 38       03P4VFKK12UO  325fafb5fa450  1541107538    55
# 80       09L0Y03JYTAC  91de23da01b00  1541034697    34
# 107      0X3OMZZH37ZS  c0cdade1ed014  1541085912     8
# 138      2WEN1MLMALJM  d89f82d2b2538  1541069999     9
# 157      3WK1Z5XPGA43  48125fbfd5e9e  1541086351    15
# 281      5BR973YOX5QD  a24a3d2fb4543  1541081113   115
# 285      6IZO9K585LAZ  c3f91fb58c16f  1541085832     3
# 290      6U61SOZBFVB4  5bbc6b805c641  1541094213     5
# 406      6Z0VOF0I5B42  38bd410cd9d0a  1541062840   116
# 425      75X35VP7UP3N  8d3ead9d73f28  1541084431    26
# 583      84WXH6LF46EW  d8ee548456f76  1541051953   147
# 586      8QPN8VULET2M  bd1865c0a29ff  1541102601     3
# 669      8UYWT5ZTUM51  44e8ce00e9285  1541103604    83
# 687      9FL3STI54XLT  96afdc225a8c3  1541041374    11
# 721      A9C6H22ROFZZ  22474812c40d6  1541067459    31
# 798      BY8W874YY1S3  07edeaf3a146e  1541113932     4
# 2743081  46044 344806 344771 148250 148243 123412 12474...
# 2743101  3873584 508896 2383659 4290518 8454334 9263300...
# 2743133  5055238 4867478 8963920 8866882 3388922 681575...
# 2743149  5216172 7110264 568061 1489531 1240361 1918193...
# 2743187  3864582 1370754 312776 514901 1241830 1627287 ...
# 2743216  2717947 503201 1859027 2673219 1668489 4073470...
# 2743218  1147447 1158944 42775 1321374 2637405 2777094 ...
# 2743222  3812150 1184108 2109618 1941951 8787616 903386...
# 2743270  2326002 889575 3814822 952209 8925 5962870 273...
# 2743289  2857762 6476770 896455 218926 2812956 5177960 ...
# 2743320  5158194 3438490 8153130 693841 2402030 6276246...
#
# [46467 rows x 5 columns]

# %%
df_out = pd.concat([df_predicted, df_not_predicted], ignore_index=True, sort=False)
#df_out.to_csv('sub_rule_based.csv')

# %%
df_out.head()
# Out:
#         user_id     session_id   timestamp  step  \
# 0  03P4VFKK12UO  325fafb5fa450  1541107538    55
# 1  09L0Y03JYTAC  91de23da01b00  1541034697    34
# 2  0X3OMZZH37ZS  c0cdade1ed014  1541085912     8
# 3  2WEN1MLMALJM  d89f82d2b2538  1541069999     9
# 4  3WK1Z5XPGA43  48125fbfd5e9e  1541086351    15
#
#                                 item_recommendations
# 0  65685 1306936 56482 2842358 6881276 63259 6539...
# 1  8561 8564 8568 8586 8588 102080 8613 55677 570...
# 2  434856 1556793 3206344 49682 1358429 658821 10...
# 3  3508086 1632525 4050606 8404976 9169816 194295...
# 4  3382114 4581320 3971456 1249659 5714694 829771...

# %%
import pandas as pd
import numpy as np
df_gt = pd.read_csv('gt.csv')
mask = (df_gt["action_type"] == "clickout item") | (df_gt["action_type"] == "interaction item rating") | (df_gt["action_type"] == "interaction item image") | (df_gt["action_type"] == "interaction item deals")
df_gt = df_gt[mask]
df_gt.head()
# Out:
#          user_id     session_id   timestamp  step             action_type  \
# 16  03P4VFKK12UO  325fafb5fa450  1541107435    17  interaction item image
# 17  03P4VFKK12UO  325fafb5fa450  1541107435    18  interaction item image
# 18  03P4VFKK12UO  325fafb5fa450  1541107457    19  interaction item image
# 19  03P4VFKK12UO  325fafb5fa450  1541107457    20  interaction item image
# 20  03P4VFKK12UO  325fafb5fa450  1541107467    21  interaction item image
#
#    reference platform              city   device current_filters impressions  \
# 16     65685       US  Bakersfield, USA  desktop             NaN         NaN
# 17     65685       US  Bakersfield, USA  desktop             NaN         NaN
# 18     65685       US  Bakersfield, USA  desktop             NaN         NaN
# 19     65685       US  Bakersfield, USA  desktop             NaN         NaN
# 20     65685       US  Bakersfield, USA  desktop             NaN         NaN
#
#    prices
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN

# %%
df_gt = df_gt[['user_id', 'session_id', 'timestamp', 'step', 'reference']]
df_gt.head()
# Out:
#          user_id     session_id   timestamp  step reference
# 16  03P4VFKK12UO  325fafb5fa450  1541107435    17     65685
# 17  03P4VFKK12UO  325fafb5fa450  1541107435    18     65685
# 18  03P4VFKK12UO  325fafb5fa450  1541107457    19     65685
# 19  03P4VFKK12UO  325fafb5fa450  1541107457    20     65685
# 20  03P4VFKK12UO  325fafb5fa450  1541107467    21     65685

# %%
df_pred_cleaned = df_predicted[['user_id', 'session_id', 'timestamp', 'step', 'all_interactions']]
df_pred_cleaned.head()
# Out:
#           user_id     session_id   timestamp  step all_interactions
# 38   03P4VFKK12UO  325fafb5fa450  1541107538    55            65685
# 84   0O1CTEP95YKQ  af793494b5f84  1541113537    22    63051 2851635
# 87   0T819ODEIRA4  7643893620070  1541085062     7          5170834
# 107  0X3OMZZH37ZS  c0cdade1ed014  1541085912     8          1358429
# 138  2WEN1MLMALJM  d89f82d2b2538  1541069999     9  3508086 4050606

# %%
df_merged = (df_pred_cleaned.merge(df_gt, left_on=['user_id', 'session_id', 'timestamp', 'step'], right_on=['user_id', 'session_id', 'timestamp', 'step'], how="left"))
df_merged.head()
# Out:
#         user_id     session_id   timestamp  step all_interactions reference
# 0  03P4VFKK12UO  325fafb5fa450  1541107538    55            65685   1320460
# 1  0O1CTEP95YKQ  af793494b5f84  1541113537    22    63051 2851635      8602
# 2  0T819ODEIRA4  7643893620070  1541085062     7          5170834   5170834
# 3  0X3OMZZH37ZS  c0cdade1ed014  1541085912     8          1358429    434856
# 4  2WEN1MLMALJM  d89f82d2b2538  1541069999     9  3508086 4050606   8404976

# %%
df_merged['result'] = df_merged.apply(lambda x: 1 if (str(x.reference) in x.all_interactions) else 0,axis=1)
df_merged.head()
# Out:
#         user_id     session_id   timestamp  step all_interactions reference  \
# 0  03P4VFKK12UO  325fafb5fa450  1541107538    55            65685   1320460
# 1  0O1CTEP95YKQ  af793494b5f84  1541113537    22    63051 2851635      8602
# 2  0T819ODEIRA4  7643893620070  1541085062     7          5170834   5170834
# 3  0X3OMZZH37ZS  c0cdade1ed014  1541085912     8          1358429    434856
# 4  2WEN1MLMALJM  d89f82d2b2538  1541069999     9  3508086 4050606   8404976
#
#    result
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0

# %%
tot_prediction = df_merged.shape[0]
correct = df_merged['result'].sum()
print('Tutte: ' + str(tot_prediction))
print('Azzeccate: ' + str(correct))
print('Percentuale: ' + str(correct/tot_prediction))
# Out:
# Tutte: 48898
# Azzeccate: 16854
# Percentuale: 0.34467667389259277

# %%
df_merged['result'].sum()
# Out:
# 16854

# %%
df_gt[df_gt['user_id'] == '6Z0VOF0I5B42']
# Out:
#           user_id     session_id   timestamp  step             action_type  \
# 408  6Z0VOF0I5B42  38bd410cd9d0a  1541061247     1  interaction item image
# 409  6Z0VOF0I5B42  38bd410cd9d0a  1541061247     2  interaction item image
# 410  6Z0VOF0I5B42  38bd410cd9d0a  1541061250     3  interaction item image
# 411  6Z0VOF0I5B42  38bd410cd9d0a  1541061250     4  interaction item image
# 412  6Z0VOF0I5B42  38bd410cd9d0a  1541061250     5  interaction item image
# 413  6Z0VOF0I5B42  38bd410cd9d0a  1541061252     6  interaction item image
# 414  6Z0VOF0I5B42  38bd410cd9d0a  1541061254     7  interaction item image
# 415  6Z0VOF0I5B42  38bd410cd9d0a  1541061256     8  interaction item image
# 416  6Z0VOF0I5B42  38bd410cd9d0a  1541061256     9  interaction item image
# 417  6Z0VOF0I5B42  38bd410cd9d0a  1541061256    10  interaction item image
# 418  6Z0VOF0I5B42  38bd410cd9d0a  1541061258    11  interaction item image
# 419  6Z0VOF0I5B42  38bd410cd9d0a  1541061258    12  interaction item image
# 420  6Z0VOF0I5B42  38bd410cd9d0a  1541061260    13  interaction item image
# 421  6Z0VOF0I5B42  38bd410cd9d0a  1541061260    14  interaction item image
# 422  6Z0VOF0I5B42  38bd410cd9d0a  1541061260    15  interaction item image
# 423  6Z0VOF0I5B42  38bd410cd9d0a  1541061262    16  interaction item image
# 424  6Z0VOF0I5B42  38bd410cd9d0a  1541061262    17  interaction item image
# 425  6Z0VOF0I5B42  38bd410cd9d0a  1541061262    18  interaction item image
# 426  6Z0VOF0I5B42  38bd410cd9d0a  1541061264    19  interaction item image
# 427  6Z0VOF0I5B42  38bd410cd9d0a  1541061264    20  interaction item image
# 428  6Z0VOF0I5B42  38bd410cd9d0a  1541061268    21  interaction item image
# 429  6Z0VOF0I5B42  38bd410cd9d0a  1541061268    22  interaction item image
# 430  6Z0VOF0I5B42  38bd410cd9d0a  1541061268    23  interaction item image
# 431  6Z0VOF0I5B42  38bd410cd9d0a  1541061268    24  interaction item image
# 432  6Z0VOF0I5B42  38bd410cd9d0a  1541061268    25  interaction item image
# 433  6Z0VOF0I5B42  38bd410cd9d0a  1541062228    26           clickout item
# 434  6Z0VOF0I5B42  38bd410cd9d0a  1541062297    27  interaction item image
# 435  6Z0VOF0I5B42  38bd410cd9d0a  1541062297    28  interaction item image
# 436  6Z0VOF0I5B42  38bd410cd9d0a  1541062307    29  interaction item image
# 437  6Z0VOF0I5B42  38bd410cd9d0a  1541062307    30  interaction item image
# ..            ...            ...         ...   ...                     ...
# 494  6Z0VOF0I5B42  38bd410cd9d0a  1541062553    87  interaction item image
# 495  6Z0VOF0I5B42  38bd410cd9d0a  1541062563    88  interaction item image
# 496  6Z0VOF0I5B42  38bd410cd9d0a  1541062563    89  interaction item image
# 497  6Z0VOF0I5B42  38bd410cd9d0a  1541062563    90  interaction item image
# 498  6Z0VOF0I5B42  38bd410cd9d0a  1541062563    91  interaction item image
# 499  6Z0VOF0I5B42  38bd410cd9d0a  1541062563    92  interaction item image
# 500  6Z0VOF0I5B42  38bd410cd9d0a  1541062563    93  interaction item image
# 501  6Z0VOF0I5B42  38bd410cd9d0a  1541062563    94  interaction item image
# 502  6Z0VOF0I5B42  38bd410cd9d0a  1541062563    95  interaction item image
# 503  6Z0VOF0I5B42  38bd410cd9d0a  1541062564    96           clickout item
# 504  6Z0VOF0I5B42  38bd410cd9d0a  1541062564    97           clickout item
# 505  6Z0VOF0I5B42  38bd410cd9d0a  1541062630    98  interaction item image
# 506  6Z0VOF0I5B42  38bd410cd9d0a  1541062630    99  interaction item image
# 507  6Z0VOF0I5B42  38bd410cd9d0a  1541062778   100  interaction item image
# 508  6Z0VOF0I5B42  38bd410cd9d0a  1541062778   101  interaction item image
# 509  6Z0VOF0I5B42  38bd410cd9d0a  1541062788   102  interaction item image
# 510  6Z0VOF0I5B42  38bd410cd9d0a  1541062788   103  interaction item image
# 511  6Z0VOF0I5B42  38bd410cd9d0a  1541062788   104  interaction item image
# 512  6Z0VOF0I5B42  38bd410cd9d0a  1541062788   105  interaction item image
# 513  6Z0VOF0I5B42  38bd410cd9d0a  1541062788   106  interaction item image
# 514  6Z0VOF0I5B42  38bd410cd9d0a  1541062788   107  interaction item image
# 515  6Z0VOF0I5B42  38bd410cd9d0a  1541062788   108  interaction item image
# 516  6Z0VOF0I5B42  38bd410cd9d0a  1541062788   109  interaction item image
# 517  6Z0VOF0I5B42  38bd410cd9d0a  1541062788   110  interaction item image
# 518  6Z0VOF0I5B42  38bd410cd9d0a  1541062788   111  interaction item image
# 519  6Z0VOF0I5B42  38bd410cd9d0a  1541062831   112  interaction item image
# 520  6Z0VOF0I5B42  38bd410cd9d0a  1541062831   113  interaction item image
# 521  6Z0VOF0I5B42  38bd410cd9d0a  1541062831   114  interaction item image
# 522  6Z0VOF0I5B42  38bd410cd9d0a  1541062831   115  interaction item image
# 523  6Z0VOF0I5B42  38bd410cd9d0a  1541062840   116           clickout item
#
#     reference platform              city  device current_filters  \
# 408     15238       FR  Honfleur, France  mobile             NaN
# 409     15238       FR  Honfleur, France  mobile             NaN
# 410     15238       FR  Honfleur, France  mobile             NaN
# 411     15238       FR  Honfleur, France  mobile             NaN
# 412     15238       FR  Honfleur, France  mobile             NaN
# 413     15238       FR  Honfleur, France  mobile             NaN
# 414     15238       FR  Honfleur, France  mobile             NaN
# 415     15238       FR  Honfleur, France  mobile             NaN
# 416     15238       FR  Honfleur, France  mobile             NaN
# 417     15238       FR  Honfleur, France  mobile             NaN
# 418     15238       FR  Honfleur, France  mobile             NaN
# 419     15238       FR  Honfleur, France  mobile             NaN
# 420     15238       FR  Honfleur, France  mobile             NaN
# 421     15238       FR  Honfleur, France  mobile             NaN
# 422     15238       FR  Honfleur, France  mobile             NaN
# 423     15238       FR  Honfleur, France  mobile             NaN
# 424     15238       FR  Honfleur, France  mobile             NaN
# 425     15238       FR  Honfleur, France  mobile             NaN
# 426     15238       FR  Honfleur, France  mobile             NaN
# 427     15238       FR  Honfleur, France  mobile             NaN
# 428     15238       FR  Honfleur, France  mobile             NaN
# 429     15238       FR  Honfleur, France  mobile             NaN
# 430     15238       FR  Honfleur, France  mobile             NaN
# 431     15238       FR  Honfleur, France  mobile             NaN
# 432     15238       FR  Honfleur, France  mobile             NaN
# 433    107827       FR  Honfleur, France  mobile             NaN
# 434    107998       FR  Honfleur, France  mobile             NaN
# 435    107998       FR  Honfleur, France  mobile             NaN
# 436   3569682       FR  Honfleur, France  mobile             NaN
# 437   3569682       FR  Honfleur, France  mobile             NaN
# ..        ...      ...               ...     ...             ...
# 494     49033       FR  Honfleur, France  mobile             NaN
# 495     49033       FR  Honfleur, France  mobile             NaN
# 496     49033       FR  Honfleur, France  mobile             NaN
# 497     49033       FR  Honfleur, France  mobile             NaN
# 498     49033       FR  Honfleur, France  mobile             NaN
# 499     49033       FR  Honfleur, France  mobile             NaN
# 500     49033       FR  Honfleur, France  mobile             NaN
# 501     49033       FR  Honfleur, France  mobile             NaN
# 502     49033       FR  Honfleur, France  mobile             NaN
# 503     49033       FR  Honfleur, France  mobile             NaN
# 504     49033       FR  Honfleur, France  mobile             NaN
# 505     49033       FR  Honfleur, France  mobile             NaN
# 506     49033       FR  Honfleur, France  mobile             NaN
# 507    341471       FR  Honfleur, France  mobile             NaN
# 508    341471       FR  Honfleur, France  mobile             NaN
# 509    341471       FR  Honfleur, France  mobile             NaN
# 510    341471       FR  Honfleur, France  mobile             NaN
# 511    341471       FR  Honfleur, France  mobile             NaN
# 512    341471       FR  Honfleur, France  mobile             NaN
# 513    341471       FR  Honfleur, France  mobile             NaN
# 514    341471       FR  Honfleur, France  mobile             NaN
# 515    341471       FR  Honfleur, France  mobile             NaN
# 516    341471       FR  Honfleur, France  mobile             NaN
# 517    341471       FR  Honfleur, France  mobile             NaN
# 518    341471       FR  Honfleur, France  mobile             NaN
# 519    341471       FR  Honfleur, France  mobile             NaN
# 520    341471       FR  Honfleur, France  mobile             NaN
# 521    341471       FR  Honfleur, France  mobile             NaN
# 522    341471       FR  Honfleur, France  mobile             NaN
# 523    341471       FR  Honfleur, France  mobile             NaN
#
#                                            impressions  \
# 408                                                NaN
# 409                                                NaN
# 410                                                NaN
# 411                                                NaN
# 412                                                NaN
# 413                                                NaN
# 414                                                NaN
# 415                                                NaN
# 416                                                NaN
# 417                                                NaN
# 418                                                NaN
# 419                                                NaN
# 420                                                NaN
# 421                                                NaN
# 422                                                NaN
# 423                                                NaN
# 424                                                NaN
# 425                                                NaN
# 426                                                NaN
# 427                                                NaN
# 428                                                NaN
# 429                                                NaN
# 430                                                NaN
# 431                                                NaN
# 432                                                NaN
# 433  107827|1284084|218636|107998|48719|3105864|498...
# 434                                                NaN
# 435                                                NaN
# 436                                                NaN
# 437                                                NaN
# ..                                                 ...
# 494                                                NaN
# 495                                                NaN
# 496                                                NaN
# 497                                                NaN
# 498                                                NaN
# 499                                                NaN
# 500                                                NaN
# 501                                                NaN
# 502                                                NaN
# 503  107827|1284084|218636|107998|48719|3105864|498...
# 504  107827|1284084|218636|107998|48719|3105864|498...
# 505                                                NaN
# 506                                                NaN
# 507                                                NaN
# 508                                                NaN
# 509                                                NaN
# 510                                                NaN
# 511                                                NaN
# 512                                                NaN
# 513                                                NaN
# 514                                                NaN
# 515                                                NaN
# 516                                                NaN
# 517                                                NaN
# 518                                                NaN
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523  107827|1284084|218636|107998|48719|3105864|498...
#
#                                                 prices
# 408                                                NaN
# 409                                                NaN
# 410                                                NaN
# 411                                                NaN
# 412                                                NaN
# 413                                                NaN
# 414                                                NaN
# 415                                                NaN
# 416                                                NaN
# 417                                                NaN
# 418                                                NaN
# 419                                                NaN
# 420                                                NaN
# 421                                                NaN
# 422                                                NaN
# 423                                                NaN
# 424                                                NaN
# 425                                                NaN
# 426                                                NaN
# 427                                                NaN
# 428                                                NaN
# 429                                                NaN
# 430                                                NaN
# 431                                                NaN
# 432                                                NaN
# 433  85|58|79|84|84|89|68|120|89|99|84|50|88|187|79...
# 434                                                NaN
# 435                                                NaN
# 436                                                NaN
# 437                                                NaN
# ..                                                 ...
# 494                                                NaN
# 495                                                NaN
# 496                                                NaN
# 497                                                NaN
# 498                                                NaN
# 499                                                NaN
# 500                                                NaN
# 501                                                NaN
# 502                                                NaN
# 503  85|58|79|84|84|89|68|120|89|99|84|50|88|187|79...
# 504  85|58|79|84|84|89|68|120|89|99|84|50|88|187|79...
# 505                                                NaN
# 506                                                NaN
# 507                                                NaN
# 508                                                NaN
# 509                                                NaN
# 510                                                NaN
# 511                                                NaN
# 512                                                NaN
# 513                                                NaN
# 514                                                NaN
# 515                                                NaN
# 516                                                NaN
# 517                                                NaN
# 518                                                NaN
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523  85|58|79|84|84|89|68|120|89|99|84|50|88|187|79...
#
# [116 rows x 12 columns]

# %%
df_merged.head(100)
# Out:
#          user_id     session_id   timestamp  step  \
# 0   03P4VFKK12UO  325fafb5fa450  1541107538    55
# 1   0O1CTEP95YKQ  af793494b5f84  1541113537    22
# 2   0T819ODEIRA4  7643893620070  1541085062     7
# 3   0X3OMZZH37ZS  c0cdade1ed014  1541085912     8
# 4   2WEN1MLMALJM  d89f82d2b2538  1541069999     9
