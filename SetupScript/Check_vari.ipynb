# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_test_c = pd.read_csv('test_cleaned.csv')
df_test_c[df_test_c['user_id'] == '3473ULL51OOW']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, user_id, session_id, timestamp, step, action_type, reference, platform, city, device, current_filters, impressions, prices]
# Index: []

# %%
df_test[df_test['user_id'] == '3473ULL51OOW']
# Out:
#               user_id     session_id   timestamp  step    action_type  \
# 1564565  3473ULL51OOW  96c35e1a5d439  1541302470     1  clickout item
# 2191591  3473ULL51OOW  96c35e1a5d439  1541396795     1  clickout item
#
#         reference platform              city  device current_filters  \
# 1564565       NaN       MX  Sayulita, Mexico  mobile             NaN
# 2191591       NaN       MX  Ensenada, Mexico  mobile             NaN
#
#                                                impressions  \
# 1564565  1843815|9716194|9703422|8973064|5781948|665457...
# 2191591  1006377|43065|1006371|1083210|9036148|1119820|...
#
#                                                     prices
# 1564565  309|2844|834|177|309|131|161|105|132|53|154|14...
# 2191591  57|56|56|106|114|79|60|120|48|135|50|57|385|36...

# %%
df_test = clean_dataset_error(df_test)
df_test.to_csv('test_cleaned.csv')

# %%
def clean_dataset_error(df):
    df = df[df['user_id'] != '3473ULL51OOW']
    return df

# %%
df_prices = pd.read_csv('hotel_prices.csv')

# %%
df_prices[df_prices['impressions'] == 2297972]
# Out:
#         impressions       price
# 241214      2297972  131.882465

# %%
df_tot = pd.concat([df_train, df_test], ignore_index=True)

# %%
df_tot[df_tot['user_id'] == 'SS4INACFPWUX']
# Out:
#                user_id     session_id   timestamp  step  \
# 16040700  SS4INACFPWUX  babd8de326bf5  1541587168     1
# 16040701  SS4INACFPWUX  babd8de326bf5  1541587168     2
# 16040702  SS4INACFPWUX  babd8de326bf5  1541587168     3
# 16040703  SS4INACFPWUX  babd8de326bf5  1541587168     4
# 16040704  SS4INACFPWUX  babd8de326bf5  1541587178     5
# 16040705  SS4INACFPWUX  babd8de326bf5  1541587178     6
# 16040706  SS4INACFPWUX  babd8de326bf5  1541587188     7
# 16040707  SS4INACFPWUX  babd8de326bf5  1541587188     8
# 16040708  SS4INACFPWUX  babd8de326bf5  1541587188     9
# 16040709  SS4INACFPWUX  babd8de326bf5  1541587188    10
# 16040710  SS4INACFPWUX  babd8de326bf5  1541587198    11
# 16040711  SS4INACFPWUX  babd8de326bf5  1541587198    12
# 16040712  SS4INACFPWUX  babd8de326bf5  1541587198    13
# 16040713  SS4INACFPWUX  babd8de326bf5  1541587198    14
# 16040714  SS4INACFPWUX  babd8de326bf5  1541587198    15
# 16040715  SS4INACFPWUX  babd8de326bf5  1541587198    16
# ...

# %%
df_train[df_train['user_id'] == 'OKEDW4LHMKDO']
# Out:
#                user_id     session_id   timestamp  step  \
# 11269963  OKEDW4LHMKDO  6d16cf00de49e  1541076767     1
#
#                      action_type reference platform                      city  \
# 11269963  interaction item deals    678691       AT  Bang Tao Beach, Thailand
#
#            device current_filters impressions prices
# 11269963  desktop             NaN         NaN    NaN

# %%
df_test[df_test['user_id'] == 'LJKUJY87L893']
# Out:
#              user_id     session_id   timestamp  step  \
# 104199  LJKUJY87L893  5aaee7d4682dd  1541661264     1
# 104200  LJKUJY87L893  5aaee7d4682dd  1541661264     2
# 104201  LJKUJY87L893  5aaee7d4682dd  1541661264     3
# 104202  LJKUJY87L893  5aaee7d4682dd  1541661264     4
# 104203  LJKUJY87L893  5aaee7d4682dd  1541661264     5
# 104204  LJKUJY87L893  5aaee7d4682dd  1541661264     6
# 104205  LJKUJY87L893  5aaee7d4682dd  1541661264     7
# 104206  LJKUJY87L893  5aaee7d4682dd  1541661265     8
# 104207  LJKUJY87L893  5aaee7d4682dd  1541661273     9
# 104208  LJKUJY87L893  5aaee7d4682dd  1541661275    10
# 104209  LJKUJY87L893  5aaee7d4682dd  1541661285    11
# 104210  LJKUJY87L893  5aaee7d4682dd  1541661305    12
# 104211  LJKUJY87L893  5aaee7d4682dd  1541661340    13
# 104212  LJKUJY87L893  5aaee7d4682dd  1541661340    14
# 104213  LJKUJY87L893  5aaee7d4682dd  1541661350    15
# 104214  LJKUJY87L893  5aaee7d4682dd  1541661350    16
# ...

# %%
df_subm = pd.read_csv('submission_popular.csv')
df_subm[df_subm['user_id'] == "H23743N5Q334"]
# Out:
#              user_id     session_id   timestamp  step  \
# 129726  H23743N5Q334  dc964e38fac3b  1541624849     6
# 226404  H23743N5Q334  ca2e5b871a11e  1541559456     6
#
#                                      item_recommendations
# 129726  55115 980153 667346 667241 5864140 6924278 719...
# 226404                                    8386650|8818012

# %%
df_subm_off = pd.read_csv('submission_popular_off.csv')
df_subm.head()
# Out:
#         user_id     session_id   timestamp  step  \
# 0  004A07DM0IDW  1d688ec168932  1541555799     7
# 1  00Y1Z24X8084  26b6d294d66e7  1541651823     2
# 2  01V3WDTDM5CU  07628a0f5be0b  1541575643     5
# 3  02AOAVF9PVYH  4a01c3afbc224  1541681278    46
# 4  0339C84S24ET  89171d441a304  1541615683    36
#
#                                 item_recommendations
# 0  2249874 1050068 3241426 2059240 399441 9030086...
# 1  3843244 9343000 1981001 4476010 7101352 779497...
# 2  2817590 6434434 2012359 7950162 3180004 287562...
# 3  2403128 559091 7304020 559056 1052958 559026 1...
# 4  4500498 5647680 37717 5773306 4957186 9500346 ...

# %%
tot_elements = df_test[df_test['reference'].isnull()].shape[0]
one_session_clickout = df_test[(df_test['action_type'] == 'clickout item') & (df_test['step'] == 1) & (df_test['reference'].isnull())]
print('There are #' + str(tot_elements) + ' in the test set')
print('# ' + str(one_session_clickout.shape[0]) + ' are clickout at the first step')
print('# ' + str(tot_elements - one_session_clickout.shape[0]) + ' are standard sessions')
# Out:
# There are #261731 in the test set
# # 60605 are clickout at the first step
# # 201126 are standard sessions

# %%
one_session_clickout.head()
# Out:
#           user_id     session_id   timestamp  step    action_type reference  \
# 513  0BZN2KFMHLZF  d9497eeb946dc  1541668916     1  clickout item       NaN
# 554  0D1XFBRWUX7Z  35e873299a45f  1541586069     1  clickout item       NaN
# 598  0EPVF4QE049Q  11b583578f7f3  1541611766     1  clickout item       NaN
# 599  0GY71I4BUBQW  334177bbc6525  1541638087     1  clickout item       NaN
# 600  0H2RFN3FXM5A  e9fa318e4aad0  1541576918     1  clickout item       NaN
#
#     platform                city   device current_filters  \
# 513       BE    Hasselt, Belgium   mobile             NaN
# 554       AU   Sydney, Australia   mobile             NaN
# 598       FI  Seinäjoki, Finland   mobile             NaN
# 599       AU         Rome, Italy  desktop             NaN
# 600       IN    Bengaluru, India   mobile             NaN
#
#                                            impressions  \
# 513  39730|133101|39758|7029236|455086|3887112|1070...
# ...

# %%
losses = [9.924517906567523, 7.371861361607947,  6.317181021518076, 5.739671815066544, 5.459720562748023, 5.162460692820658, 5.00199950781184, 4.860978505860151, 4.823992248418677, 4.636060707004925, 4.512758187932216, 4.377258799967875, 4.275113186921176, 4.178863005686655, 4.071428351778414, 3.9695264417342555, 3.908020982159913, 3.793796694660915, 3.718747284200052, 3.625303214585205]
acc = [0.4903783308138147, 0.6036883211342748, 0.614242281575438, 0.617085157132392,  0.608824034585693, 0.6169324078458299, 0.6166166251030893, 0.620711478105622, 0.6263582356937566, 0.6264270518400638, 0.6260504359302239, 0.6286026474664703, 0.6099115420628957, 0.6243029777839372, 0.6053100447542613, 0.6153528888393531, 0.6101258997587955, 0.6256632825746854, 0.6134930671825668, 0.6325988747830421]
# Out:
#   File "<ipython-input-7-c3c1ec25cc22>", line 1
#     losses = [9,924517906567523, 7,371861361607947,  6,317181021518076, 5,739671815066544, 5,459720562748023, 5,162460692820658, 5,00199950781184, 4,860978505860151, 4,823992248418677, 4,636060707004925, 4,512758187932216, 4,377258799967875, 4,275113186921176, 4,178863005686655, 4,071428351778414, 3,9695264417342555, 3,908020982159913, 3,793796694660915, 3,718747284200052, 3,625303214585205]
#                                                                                                                                                 ^
# SyntaxError: invalid token

# %%
plt.figure()
plt.plot(losses)

# %%
plt.figure()
plt.plot(acc)
