# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_loss = pd.read_csv('./results/rnn_cuda_batch_sub_loss.csv')
df_acc = pd.read_csv('./results/rnn_cuda_batch_sub_acc.csv')

# %%
--encode
--epochs 20 
--ncomponents 100 
--window 3 
--learnrate 0.0001 
--iscuda 
--subname rnn_cuda_batch_sub 
--numthread 4 
--batchsize 32

# %%
plt.figure()
plt.plot(df_loss)

plt.figure()
plt.plot(df_acc)

# %%
df_loss = pd.read_csv('./results/rnn_cuda_sub_loss.csv')
df_acc = pd.read_csv('./results/rnn_cuda_sub_acc.csv')

# %%
--epochs 20
--ncomponents 100 
--window 3 
--learnrate 0.0001 
--iscuda 
--subname rnn_cuda_batch_sub 
--numthread 4 
--batchsize 0

# %%
plt.figure()
plt.plot(df_loss)

plt.figure()
plt.plot(df_acc)

# %%
df_local = pd.read_csv('./train_1.csv')

# %%
df_colab = pd.read_csv('./train_colab.csv')

# %%
#Serious results

# %%
#--encode ./encode_1.csv 
#--meta ./item_metadata.csv 
#--train ./train_1.csv 
#--test ./test_1.csv 
#--gt ./gt_1.csv 
#--isimpression 
#--isdrop 
#--hiddendim 1000 
#--epochs 50 
#--ncomponents 100 
#--window 3 
#--learnrate 0.001 
#--iscuda 
#--subname rnn_1%_sub 
#--numthread 4 
#--batchsize 16

# %%
def plotn(n, perc):
    df_loss = pd.read_csv('./results/#' + str(n) + '/rnn_' + str(perc) + '%_sub_loss.csv')
    df_acc = pd.read_csv('./results/#' + str(n) + '/rnn_' + str(perc) + '%_sub_acc.csv')
    plt.figure()
    plt.plot(df_loss)
    plt.figure()
    plt.plot(df_acc)

# %%
plotn(1, 1)

# %%
#2
#--encode ./encode_10.csv
#--meta ./item_metadata.csv 
#--train ./train_10.csv 
#--test ./test_10.csv 
#--gt ./gt_10.csv 
#--isimpression 
#--isdrop 
#--hiddendim 1000 
#--epochs 20 
#--ncomponents 100 
#--window 3 
#--learnrate 0.001 
#--iscuda 
#--subname rnn_10%_sub 
#—numthread 2 
#--batchsize 64

# %%
plotn(2, 10)

# %%
#python setup.py 
#--encode ./encode_1.csv 
#--meta ./item_metadata.csv 
#--train ./train_1.csv 
#--test ./test_1.csv 
#--gt ./gt_1.csv 
#--isimpression 
#--isdrop 
#--hiddendim 1500
#--epochs 50 
#--ncomponents 100 
#--window 3 
#--learnrate 0.001 
#--iscuda 
#--subname rnn_1%_sub 
#--numthread 4 
#--batchsize 16

# %%
plotn(3, 1)

# %%
#4
#--encode ./encode_1.csv 
#--meta ./item_metadata.csv 
#--train ./train_1.csv 
#--test ./test_1.csv 
#--gt ./gt_1.csv 
#--isimpression 
#--isdrop 
#--hiddendim 200
#--epochs 50 
#--ncomponents 100 
#--window 3 
#--learnrate 0.001 
#--iscuda 
#--subname rnn_1%_sub 
#--numthread 4 
#--batchsize 16

# %%
plotn(4, 1)

# %%
#5
SBATCH: 91010
python setup.py --encode ./encode_1.csv --meta ./item_metadata.csv --train ./train_1.csv --test ./test_1.csv --gt ./gt_1.csv --isimpression --isdrop --hiddendim 200 --epochs 50 --ncomponents 100 --window 3 --learnrate 0.001 --iscuda --subname rnn_1%_sub --numthread 4 --batchsize 16

# %%
plotn(5, 1)

# %%
#6
SBATCH: 91000
--encode ./encode_10.csv 
--meta ./item_metadata.csv 
--train ./train_10.csv 
--test ./test_10.csv 
--gt ./gt_10.csv 
--isimpression 
--isdrop 
--hiddendim 1000 
--epochs 20 
--ncomponents 100 
--window 3 
--learnrate 0.001 
--iscuda 
--subname rnn_10%_sub 
-—numthread 2 
--batchsize 32
tempo: 661m

# %%
plotn(6, 10)

# %%
#7
#SBATCH: 91011
#--encode ./encode_10.csv 
#--meta ./item_metadata.csv 
#--train ./train_10.csv 
#--test ./test_10.csv 
#--gt ./gt_10.csv 
#--isimpression 
#--isdrop 
#--hiddendim 200 
#--epochs 20 
#--ncomponents 100 
#--window 3 
#--learnrate 0.001 
#--iscuda 
#--subname rnn_10%_sub 
#--numthread 2 
#--batchsize 16
#tempo: 564m

# %%
plotn(7, 10)

# %%
#reverse

# %%
#8
SBATCH 95320
python setup.py --encode ./encode_10.csv --meta ./item_metadata.csv --train ./train_10.csv --test ./test_10.csv --gt ./gt_10.csv --isimpression --hiddendim 150 --epochs 20 --ncomponents 100 --window 5 --learnrate 0.001 --iscuda --subname rnn_10%_sub --numthread 2 --batchsize 32

# %%
plotn(8, 10)

# %%
#9
SBATCH 95321
python setup.py --encode ./encode_10.csv --meta ./item_metadata.csv --train ./train_10.csv --test ./test_10.csv --gt ./gt_10.csv --isimpression --hiddendim 200 --epochs 30 --ncomponents 100 --window 5 --learnrate 0.001 --iscuda --subname rnn_10%_sub --numthread 2 --batchsize 32

# %%
plotn(9, 10)

# %%
plotn(11, 10)
